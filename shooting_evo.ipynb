# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv("./NBA_stats/Player Shooting.csv")

# %%
d1
# Out:
#        seas_id  season  player_id           player  birth_year pos  age  \
# 0        30458    2023       5025       A.J. Green         NaN  SG   23
# 1        30459    2023       5026      A.J. Lawson         NaN  SG   22
# 2        30460    2023       5026      A.J. Lawson         NaN  SG   22
# 3        30461    2023       5026      A.J. Lawson         NaN  SG   22
# 4        30462    2023       4219     Aaron Gordon         NaN  PF   27
# ...        ...     ...        ...              ...         ...  ..  ...
# 16045    15655    1997       2478  Willie Anderson         NaN  SG   30
# 16046    15656    1997       2632    Willie Burton         NaN  SF   28
# 16047    15657    1997       2278  Xavier McDaniel         NaN  PF   33
# 16048    15658    1997       2890       Yinka Dare         NaN   C   24
# 16049    15659    1997       2891        Žan Tabak         NaN   C   26
#
#        experience   lg   tm  ...  fg_percent_from_x16_3p_range  \
# ...

# %%
d1.shape
# Out:
# (16050, 34)

# %%
d1.columns
# Out:
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'mp', 'fg_percent', 'avg_dist_fga',
#        'percent_fga_from_x2p_range', 'percent_fga_from_x0_3_range',
#        'percent_fga_from_x3_10_range', 'percent_fga_from_x10_16_range',
#        'percent_fga_from_x16_3p_range', 'percent_fga_from_x3p_range',
#        'fg_percent_from_x2p_range', 'fg_percent_from_x0_3_range',
#        'fg_percent_from_x3_10_range', 'fg_percent_from_x10_16_range',
#        'fg_percent_from_x16_3p_range', 'fg_percent_from_x3p_range',
#        'percent_assisted_x2p_fg', 'percent_assisted_x3p_fg',
#        'percent_dunks_of_fga', 'num_of_dunks', 'percent_corner_3s_of_3pa',
#        'corner_3_point_percent', 'num_heaves_attempted', 'num_heaves_made'],
#       dtype='object')

# %%
d1['player'].nunique()
# Out:
# 2539

# %%
d1.dtypes
# Out:
# seas_id                            int64
# season                             int64
# player_id                          int64
# player                            object
# birth_year                       float64
# pos                               object
# age                                int64
# experience                         int64
# lg                                object
# tm                                object
# g                                  int64
# mp                                 int64
# fg_percent                       float64
# avg_dist_fga                     float64
# percent_fga_from_x2p_range       float64
# percent_fga_from_x0_3_range      float64
# percent_fga_from_x3_10_range     float64
# percent_fga_from_x10_16_range    float64
# percent_fga_from_x16_3p_range    float64
# percent_fga_from_x3p_range       float64
# fg_percent_from_x2p_range        float64
# fg_percent_from_x0_3_range       float64
# fg_percent_from_x3_10_range      float64
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16050 entries, 0 to 16049
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   seas_id                        16050 non-null  int64
#  1   season                         16050 non-null  int64
#  2   player_id                      16050 non-null  int64
#  3   player                         16050 non-null  object
#  4   birth_year                     196 non-null    float64
#  5   pos                            16050 non-null  object
#  6   age                            16050 non-null  int64
#  7   experience                     16050 non-null  int64
#  8   lg                             16050 non-null  object
#  9   tm                             16050 non-null  object
#  10  g                              16050 non-null  int64
#  11  mp                             16050 non-null  int64
# ...

# %%
d1.describe()
# Out:
#             seas_id        season     player_id   birth_year           age  \
# count  16050.000000  16050.000000  16050.000000   196.000000  16050.000000
# mean   23110.500000   2010.778879   3637.334268  1978.994898     26.710717
# std     4633.380246      7.870716    655.877105     8.677999      4.257915
# min    15086.000000   1997.000000   1723.000000  1957.000000     18.000000
# 25%    19098.250000   2004.000000   3139.000000  1975.000000     23.000000
# 50%    23110.500000   2011.000000   3613.000000  1980.000000     26.000000
# 75%    27122.750000   2018.000000   4127.750000  1985.000000     30.000000
# max    31135.000000   2023.000000   5108.000000  2002.000000     44.000000
#
#          experience             g            mp    fg_percent  avg_dist_fga  \
# count  16050.000000  16050.000000  16050.000000  15955.000000  15955.000000
# mean       5.623364     45.485109   1053.889408      0.433428     12.468605
# ...

# %%
d1.head(1)
# Out:
#    seas_id  season  player_id      player  birth_year pos  age  experience  \
# 0    30458    2023       5025  A.J. Green         NaN  SG   23           1
#
#     lg   tm  ...  fg_percent_from_x16_3p_range  fg_percent_from_x3p_range  \
# 0  NBA  MIL  ...                         0.444                      0.419
#
#    percent_assisted_x2p_fg  percent_assisted_x3p_fg  percent_dunks_of_fga  \
# 0                    0.778                    0.909                   0.0
#
#    num_of_dunks  percent_corner_3s_of_3pa  corner_3_point_percent  \
# 0             0                      0.21                   0.409
#
#    num_heaves_attempted  num_heaves_made
# 0                     0                0
#
# [1 rows x 34 columns]

# %%
d1=d1[[#'seas_id',
    'season', #'player_id',
    'player', #'birth_year', 
    'pos', 'age',
       'experience', #'lg', 
    'tm', 'g', 'mp', 'fg_percent', 'avg_dist_fga',
       'percent_fga_from_x2p_range', 'percent_fga_from_x0_3_range',
       'percent_fga_from_x3_10_range', 'percent_fga_from_x10_16_range',
       'percent_fga_from_x16_3p_range', 'percent_fga_from_x3p_range',
       'fg_percent_from_x2p_range', 'fg_percent_from_x0_3_range',
       'fg_percent_from_x3_10_range', 'fg_percent_from_x10_16_range',
       'fg_percent_from_x16_3p_range', 'fg_percent_from_x3p_range',
       'percent_assisted_x2p_fg', 'percent_assisted_x3p_fg',
       'percent_dunks_of_fga', 'num_of_dunks', 'percent_corner_3s_of_3pa',
       'corner_3_point_percent', #'num_heaves_attempted', 'num_heaves_made'
]].copy()

# %%
d1
# Out:
#        season           player pos  age  experience   tm   g    mp  \
# 0        2023       A.J. Green  SG   23           1  MIL  35   345
# 1        2023      A.J. Lawson  SG   22           1  TOT  15   108
# 2        2023      A.J. Lawson  SG   22           1  MIN   1     2
# 3        2023      A.J. Lawson  SG   22           1  DAL  14   106
# 4        2023     Aaron Gordon  PF   27           9  DEN  68  2055
# ...       ...              ...  ..  ...         ...  ...  ..   ...
# 16045    1997  Willie Anderson  SG   30           9  MIA  28   303
# 16046    1997    Willie Burton  SF   28           6  ATL  24   380
# 16047    1997  Xavier McDaniel  PF   33          11  NJN  62  1170
# 16048    1997       Yinka Dare   C   24           3  NJN  41   313
# 16049    1997        Žan Tabak   C   26           3  TOR  13   218
#
#        fg_percent  avg_dist_fga  ...  fg_percent_from_x3_10_range  \
# 0           0.424          23.7  ...                        0.500
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
d1
# Out:
#        season           player pos  age  experience   tm   g    mp  \
# 0        2023       A.J. Green  SG   23           1  MIL  35   345
# 1        2023      A.J. Lawson  SG   22           1  TOT  15   108
# 2        2023      A.J. Lawson  SG   22           1  MIN   1     2
# 3        2023      A.J. Lawson  SG   22           1  DAL  14   106
# 4        2023     Aaron Gordon  PF   27           9  DEN  68  2055
# ...       ...              ...  ..  ...         ...  ...  ..   ...
# 16045    1997  Willie Anderson  SG   30           9  MIA  28   303
# 16046    1997    Willie Burton  SF   28           6  ATL  24   380
# 16047    1997  Xavier McDaniel  PF   33          11  NJN  62  1170
# 16048    1997       Yinka Dare   C   24           3  NJN  41   313
# 16049    1997        Žan Tabak   C   26           3  TOR  13   218
#
#        fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# 0           0.424          23.7                       0.160
# ...

# %%
new_col_names={
    'pos':'position', 
    'tm':'team', 'g':'games', 'mp':'min_played'}

# %%
d1=d1.rename(columns=new_col_names)

# %%
d1.isna().sum()
# Out:
# season                              0
# player                              0
# position                            0
# age                                 0
# experience                          0
# team                                0
# games                               0
# min_played                          0
# fg_percent                         95
# avg_dist_fga                       95
# percent_fga_from_x2p_range         95
# percent_fga_from_x0_3_range        95
# percent_fga_from_x3_10_range       95
# percent_fga_from_x10_16_range      95
# percent_fga_from_x16_3p_range      95
# percent_fga_from_x3p_range         95
# fg_percent_from_x2p_range         166
# fg_percent_from_x0_3_range        530
# fg_percent_from_x3_10_range       860
# fg_percent_from_x10_16_range     1235
# fg_percent_from_x16_3p_range     1319
# fg_percent_from_x3p_range        2366
# percent_assisted_x2p_fg           439
# percent_assisted_x3p_fg          4475
# percent_dunks_of_fga               95
# ...

# %%
d1[d1['fg_percent'].isna()]
# Out:
#        season              player position  age  experience team  games  \
# 16       2023    Alondes Williams       SG   23           1  BRK      1
# 467      2023  Michael Foster Jr.       PF   20           1  PHI      1
# 488      2023         Moses Brown        C   23           4  BRK      2
# 686      2022          Ade Murkey       SG   24           1  SAC      1
# 756      2022          C.J. Miles       SG   34          16  BOS      1
# ...       ...                 ...      ...  ...         ...  ...    ...
# 15311    1998    Michael McDonald        C   28           1  CHH      1
# 15468    1998  William Cunningham        C   23           1  PHI      1
# 15542    1997         Bruce Bowen       SF   25           1  MIA      1
# 15861    1997           Matt Fish        C   27           3  MIA      1
# 16033    1997       Vincent Askew       SG   30           8  NJN      1
#
#        min_played  fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# ...

# %%
d1=d1.dropna(subset='fg_percent')

# %%
d1.isna().sum()
# Out:
# season                              0
# player                              0
# position                            0
# age                                 0
# experience                          0
# team                                0
# games                               0
# min_played                          0
# fg_percent                          0
# avg_dist_fga                        0
# percent_fga_from_x2p_range          0
# percent_fga_from_x0_3_range         0
# percent_fga_from_x3_10_range        0
# percent_fga_from_x10_16_range       0
# percent_fga_from_x16_3p_range       0
# percent_fga_from_x3p_range          0
# fg_percent_from_x2p_range          71
# fg_percent_from_x0_3_range        435
# fg_percent_from_x3_10_range       765
# fg_percent_from_x10_16_range     1140
# fg_percent_from_x16_3p_range     1224
# fg_percent_from_x3p_range        2271
# percent_assisted_x2p_fg           344
# percent_assisted_x3p_fg          4380
# percent_dunks_of_fga                0
# ...

# %%
d1[d1['fg_percent_from_x2p_range'].isna()]
# Out:
#        season          player position  age  experience team  games  \
# 240      2023   Jacob Gilyard       PG   24           1  MEM      1
# 265      2023  Jamaree Bouyea       PG   23           1  WAS      1
# 597      2023   Stanley Umude       SG   23           1  DET      1
# 639      2023    Trevor Keels       SG   19           1  NYK      3
# 711      2022    Anthony Lamb       SF   24           2  SAS      2
# ...       ...             ...      ...  ...         ...  ...    ...
# 10658    2007       Von Wafer       SF   21           2  LAC      1
# 10765    2006   Charles Smith       SG   30           5  DEN      1
# 13149    2002    Jud Buechler       SF   33          12  PHO      6
# 14161    2000   Jason Miskiri       PG   24           1  CHH      1
# 14909    1999   Tyson Wheeler       PG   23           1  DEN      1
#
#        min_played  fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# 240            41       0.333          24.4                         0.0
# ...

# %%
d1=d1.dropna(subset='fg_percent_from_x2p_range')

# %%
d1.isna().sum()
# Out:
# season                              0
# player                              0
# position                            0
# age                                 0
# experience                          0
# team                                0
# games                               0
# min_played                          0
# fg_percent                          0
# avg_dist_fga                        0
# percent_fga_from_x2p_range          0
# percent_fga_from_x0_3_range         0
# percent_fga_from_x3_10_range        0
# percent_fga_from_x10_16_range       0
# percent_fga_from_x16_3p_range       0
# percent_fga_from_x3p_range          0
# fg_percent_from_x2p_range           0
# fg_percent_from_x0_3_range        364
# fg_percent_from_x3_10_range       694
# fg_percent_from_x10_16_range     1069
# fg_percent_from_x16_3p_range     1153
# fg_percent_from_x3p_range        2271
# percent_assisted_x2p_fg           273
# percent_assisted_x3p_fg          4338
# percent_dunks_of_fga                0
# ...

# %%
d1
# Out:
#        season           player position  age  experience team  games  \
# 0        2023       A.J. Green       SG   23           1  MIL     35
# 1        2023      A.J. Lawson       SG   22           1  TOT     15
# 2        2023      A.J. Lawson       SG   22           1  MIN      1
# 3        2023      A.J. Lawson       SG   22           1  DAL     14
# 4        2023     Aaron Gordon       PF   27           9  DEN     68
# ...       ...              ...      ...  ...         ...  ...    ...
# 16045    1997  Willie Anderson       SG   30           9  MIA     28
# 16046    1997    Willie Burton       SF   28           6  ATL     24
# 16047    1997  Xavier McDaniel       PF   33          11  NJN     62
# 16048    1997       Yinka Dare        C   24           3  NJN     41
# 16049    1997        Žan Tabak        C   26           3  TOR     13
#
#        min_played  fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# ...

# %%
d1.duplicated().sum()
# Out:
# 0

# %%
dup_all=d1[d1.duplicated(subset=['season','player'],keep=False)]

# %%
not_tot=dup_all[dup_all['team']!='TOT']

# %%
not_tot
# Out:
#        season          player position  age  experience team  games  \
# 2        2023     A.J. Lawson       SG   22           1  MIN      1
# 3        2023     A.J. Lawson       SG   22           1  DAL     14
# 43       2023    Bones Hyland       PG   22           2  DEN     42
# 44       2023    Bones Hyland       PG   22           2  LAC     14
# 53       2023  Bruno Fernando        C   24           4  HOU     31
# ...       ...             ...      ...  ...         ...  ...    ...
# 15993    1997  Stephen Howard       SF   26           3  UTA     42
# 16019    1997      Tony Dumas       SG   24           3  DAL     18
# 16020    1997      Tony Dumas       SG   24           3  PHO      6
# 16034    1997   Vincent Askew       SG   30           8  IND     41
# 16035    1997   Vincent Askew       SG   30           8  DEN      1
#
#        min_played  fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# 2               2       1.000           0.5                       1.000
# ...

# %%
to_drop=[]
for index,row in not_tot.iterrows():
    to_drop.append(index)

# %%
d1=d1.drop(index=to_drop).copy()

# %%
d1.duplicated(subset=['season','player']).sum()
# Out:
# 0

# %%
d1.reset_index(inplace=True,drop=True)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12744 entries, 0 to 12743
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   season                         12744 non-null  int64
#  1   player                         12744 non-null  object
#  2   position                       12744 non-null  object
#  3   age                            12744 non-null  int64
#  4   experience                     12744 non-null  int64
#  5   team                           12744 non-null  object
#  6   games                          12744 non-null  int64
#  7   min_played                     12744 non-null  int64
#  8   fg_percent                     12744 non-null  float64
#  9   avg_dist_fga                   12744 non-null  float64
#  10  percent_fga_from_x2p_range     12744 non-null  float64
#  11  percent_fga_from_x0_3_range    12744 non-null  float64
# ...

# %%
d1['position']=d1['position'].astype('category')

# %%
d1['season']=d1['season'].astype('int16')

# %%
d1['age']=d1['age'].astype('int8')

# %%
d1['experience']=d1['experience'].astype('int8')

# %%
d1['games'].max()
# Out:
# 85

# %%
d1['games']=d1['games'].astype('int8')

# %%
d1['min_played']=d1['min_played'].astype('int8')

# %%
d1['num_of_dunks'].max()
# Out:
# 306

# %%
d1['num_of_dunks']=d1['num_of_dunks'].astype('int16')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12744 entries, 0 to 12743
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   season                         12744 non-null  int16
#  1   player                         12744 non-null  object
#  2   position                       12744 non-null  category
#  3   age                            12744 non-null  int8
#  4   experience                     12744 non-null  int8
#  5   team                           12744 non-null  object
#  6   games                          12744 non-null  int8
#  7   min_played                     12744 non-null  int8
#  8   fg_percent                     12744 non-null  float64
#  9   avg_dist_fga                   12744 non-null  float64
#  10  percent_fga_from_x2p_range     12744 non-null  float64
#  11  percent_fga_from_x0_3_range    12744 non-null  float64
# ...

# %% [markdown]
# ## data prep done

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### This is the dataset I am going to work on.

# %%
d1
# Out:
#        season           player position  age  experience team  games  \
# 0        2023       A.J. Green       SG   23           1  MIL     35
# 1        2023      A.J. Lawson       SG   22           1  TOT     15
# 2        2023     Aaron Gordon       PF   27           9  DEN     68
# 3        2023    Aaron Holiday       PG   26           5  ATL     63
# 4        2023    Aaron Nesmith       SF   23           3  IND     73
# ...       ...              ...      ...  ...         ...  ...    ...
# 12739    1997  Willie Anderson       SG   30           9  MIA     28
# 12740    1997    Willie Burton       SF   28           6  ATL     24
# 12741    1997  Xavier McDaniel       PF   33          11  NJN     62
# 12742    1997       Yinka Dare        C   24           3  NJN     41
# 12743    1997        Žan Tabak        C   26           3  TOR     13
#
#        min_played  fg_percent  avg_dist_fga  percent_fga_from_x2p_range  \
# ...

# %% [markdown]
# ### The point of the analysis is to show the evolution of NBA shooting throughout the last ~25 years, so of course I will mainly need the data grouped by season.

# %%
by_season=d1.groupby('season')

# %% [markdown]
# ### Let's start by looking at the overall shooting efficiency. In general it has been increasing with an over 2 percentage point drop around 2012 (perhaps the effect of shortened lockout season?). Current shooting efficiency is by far the highest in the last quarter-century with ~46.5%.

# %%
by_season['fg_percent'].mean().plot(lw=3,title='Overall shooting efficiency',colormap='Dark2',xlabel='Season',\
                                    ylabel='Field Goal %',grid=True);

# %% [markdown]
# ### When we look at the number of players shooting over 50% from the field, the graph turns out to be quite similar to the previous one, with the number of >50% shooters reaching 100 this season.

# %%
d1.query("fg_percent>=0.5 & games>=41").groupby('season').count()['player'].plot(lw=3,title='Number of 50%+ FG players',colormap='Dark2',xlabel='Season',\
                                    ylabel='Number of players',grid=True);

# %% [markdown]
# ### One could think that's because players have been shooting from closer to the basket, right? It's easier to score standing closer, isn't it? Well, let's see....

# %%
by_season['avg_dist_fga'].mean().plot(lw=3,title='Average shot distance',colormap='Dark2',xlabel='Season',\
                                      ylabel='Distance in feet',grid=True);

# %% [markdown]
# ### The evolution of shooting assumes shooting from further away, almost 3 feet further compared to ~2002/2003. When we take a look at the number of 2-point shots attempted, the drop has been quite shocking and very constant - basically 25 pp since the end of the Jordan era.

# %%
by_season['percent_fga_from_x2p_range'].mean().plot(lw=3,title='% of 2-pointers taken',colormap='Dark2',xlabel='Season',\
                                    ylabel='% of total shots taken',grid=True);

# %% [markdown]
# ### Shooting from the paint, however, has remained stable, at a little less than 50% of all shots taken.

# %%
ax=by_season[['percent_fga_from_x0_3_range','percent_fga_from_x3_10_range']].mean().plot(kind='area',title='Shooting from the paint',\
                                                                                      colormap='Dark2',xlabel='Season',\
                                                                                      ylabel='% of total shots taken',\
                                                                                         grid=True)
h,l=ax.get_legend_handles_labels()
ax.legend(h[0:2],['%FGA from 0-3ft','%FGA from 3-10ft range']);

# %% [markdown]
# ### And here comes the midrange, the archenemy of modern basketball. Since 2004 it has been going down constantly, from 36-37% of total shots taken to slightly less than 15%. It is the least efficient type of shot and teams know it.

# %%
ax=by_season[['percent_fga_from_x10_16_range','percent_fga_from_x16_3p_range']].mean().plot(kind='area',title='Shooting from mid range',\
                                                                                      colormap='Dark2',xlabel='Season',\
                                                                                      ylabel='% of total shots taken',\
                                                                                     grid=True)
h,l=ax.get_legend_handles_labels()
ax.legend(h[0:2],['%FGA from 10-16ft','%FGA from 16ft-3pt line'],loc='lower left');

# %% [markdown]
# ### And why is it so inefficient? Let's look:

# %%
by_season[['fg_percent_from_x10_16_range','fg_percent_from_x16_3p_range']].mean().plot(lw=3,title='Midrange shooting efficiency',colormap='Dark2',xlabel='Season',\
                                      ylabel='FG%',grid=True)
plt.legend(['10-16ft','16ft-3pt line'],loc='lower right');

# %% [markdown]
# ### Basically an under 40% shot worth only 2 points. But we know what an efficient shot is, right? It is the dunk:

# %%
by_season['percent_dunks_of_fga'].mean().plot(lw=3,title='% of dunks',colormap='Dark2',xlabel='Season',\
                                    ylabel='% of total shots taken',grid=True);

# %% [markdown]
# ### The dunks have been on the rise, as have the 3-pointers:

# %%
by_season['percent_fga_from_x3p_range'].mean().plot(lw=3,title='% of 3-pointers taken',colormap='Dark2',xlabel='Season',\
                                    ylabel='% of total shots taken',grid=True);

# %% [markdown]
# ### 40% of total shots taken is an insane number. The rise has been extremely fast and we all owe it to the one and only, Stephen Curry. Let's take a look at the corner threes now:

# %%
by_season['percent_corner_3s_of_3pa'].mean().plot(lw=3,title='% of corner 3s taken',colormap='Dark2',xlabel='Season',\
                                    ylabel='% of total 3s taken',grid=True);

# %% [markdown]
# ### Corner threes were recognized as en efficient shot relatively early. There's no rocket science to that: it's the closest to the basket type of three. More than a quarter of all threes have come from the corners almost every year since around 2005.

# %% [markdown]
# ### More threes attempted should mean a decline in efficiency, shouldn't it? Well, no. Players take more threes because they are getting better and better at them:

# %%
axes=by_season[['percent_fga_from_x3p_range','fg_percent_from_x3p_range']].mean().plot(lw=3,subplots=True,\
                                                                                       title='% of 3-pointers taken vs 3FG%',\
                                                                                       colormap='Dark2',\
                                                                                       xlabel='Season',\
                                                                                       grid=True,\
                                                                                      legend=False)
axes[0].set_ylabel('% total shots taken')
axes[1].set_ylabel('3P FG%');

# %% [markdown]
# ### When it comes to team play, the number of shots assisted has been on a delicate rise for the 3-pointers, from around 83% at the and of the 20th century to around 88% now. As far as the twos are concerned, the difference is not big, from ~56% in 1997 to 55% now:

# %%
by_season[['percent_assisted_x2p_fg','percent_assisted_x3p_fg']].mean().plot(lw=3,title='% of FG assisted',colormap='Dark2',xlabel='Season',\
                                      ylabel='% FG assisted',grid=True)
plt.legend(['2-pointers','3-pointers'],loc='center');

# %%
field_goal_pcts=d1[['player','season','fg_percent_from_x2p_range','fg_percent_from_x0_3_range','fg_percent_from_x3_10_range','fg_percent_from_x10_16_range','fg_percent_from_x16_3p_range','fg_percent_from_x3p_range']]

# %%
field_goal_pcts.head()
# Out:
#           player  season  fg_percent_from_x2p_range  \
# 0     A.J. Green    2023                      0.450
# 1    A.J. Lawson    2023                      0.632
# 2   Aaron Gordon    2023                      0.628
# 3  Aaron Holiday    2023                      0.424
# 4  Aaron Nesmith    2023                      0.496
#
#    fg_percent_from_x0_3_range  fg_percent_from_x3_10_range  \
# 0                       0.400                        0.500
# 1                       0.714                        0.400
# 2                       0.782                        0.388
# 3                       0.612                        0.216
# 4                       0.639                        0.263
#
#    fg_percent_from_x10_16_range  fg_percent_from_x16_3p_range  \
# 0                         0.500                         0.444
# 1                           NaN                           NaN
# 2                         0.286                         0.357
# ...

# %%
field_goal_pcts_season=field_goal_pcts.groupby('season')

# %% [markdown]
# ### To sum it up, we can take a look at a graph showing that shooting efficiency has risen no matter the type of shot. The players are simply getting better.

# %%
field_goal_pcts_season.mean().plot(figsize=(20,15),lw=5,grid=True,colormap='Dark2')
plt.title('General shooting efficiency',fontsize=35)
plt.xlabel('Season',fontsize=20)
plt.ylabel('FG%',fontsize=20)
plt.tick_params(axis='both', labelsize=20)
plt.legend(labels=['FG% 2-pointers','FG% from 0-3ft','FG% from 3-10ft','FG% from 10-16ft','FG% from 16ft-3pt line','FG% 3-pointers'],
           title='Shot type',title_fontsize=25,fontsize=20,bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0,\
          frameon=False);

# %% [markdown]
# ### As a conclusion we can definitely say that teams have practically eliminated the midrange game at the cost of the 3-point shot. Shooting from close to the basket has always been known to be effective (again, no rocket science) but the fact that the 3-point shot is literally worth three points has drastically changed the game and forced players to improve their skillsets to adjust to modern offenses.
